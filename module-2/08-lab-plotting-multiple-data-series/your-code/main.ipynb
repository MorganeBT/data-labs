# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data.describe()
# Out:
#                 Year          Month    RetailSales  RetailTransfers  \
# count  128355.000000  128355.000000  128355.000000    128355.000000
# mean     2017.206030       7.079303       6.563037         7.188161
# std         0.404454       3.645826      28.924944        30.640156
# min      2017.000000       1.000000      -6.490000       -27.660000
# 25%      2017.000000       5.000000       0.000000         0.000000
# 50%      2017.000000       8.000000       0.330000         0.000000
# 75%      2017.000000      10.000000       3.250000         4.000000
# max      2018.000000      12.000000    1616.600000      1587.990000
#
#        WarehouseSales
# count   128355.000000
# mean        22.624213
# std        239.693277
# min      -4996.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max      16271.750000

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
barchart = data[["RetailSales", "RetailTransfers", "WarehouseSales"]].groupby(data["ItemType"]).agg("sum")
barchart.plot.bar(figsize = (10,10), grid = True)

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data['totalsale'] = data["RetailSales"] + data["WarehouseSales"]
data2 = data.sort_values('totalsale')
barhchart_df = data.groupby(data["Supplier"]).agg("sum").sort_values(by = "totalsale", ascending = False).head(10)
barhchart_df = barhchart_df[["RetailSales","RetailTransfers", "WarehouseSales"]]
barhchart_df.plot.barh(figsize = (10,10))

# %%
data2
# Out:
#         Year  Month                Supplier ItemCode  \
# 60378   2017     10      ANHEUSER BUSCH INC      175
# 19863   2017      6      ANHEUSER BUSCH INC      175
# 33435   2017      8      ANHEUSER BUSCH INC      175
# 74016   2017     11      ANHEUSER BUSCH INC      175
# 102952  2018      1      ANHEUSER BUSCH INC      175
# 47004   2017      9      ANHEUSER BUSCH INC      175
# 88537   2017     12      ANHEUSER BUSCH INC      175
# 116298  2018      2      ANHEUSER BUSCH INC      175
# 87410   2017     11                     NaN       BC
# 101909  2017     12                     NaN       BC
# 72878   2017     10                     NaN       BC
# 60629   2017     10      ANHEUSER BUSCH INC      205
# 20102   2017      6      ANHEUSER BUSCH INC      205
# 33696   2017      8      ANHEUSER BUSCH INC      205
# 47259   2017      9      ANHEUSER BUSCH INC      205
# 74283   2017     11      ANHEUSER BUSCH INC      205
# 103208  2018      1      ANHEUSER BUSCH INC      205
# ...

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data.groupby(["Year", "Month" ])["RetailSales", "RetailTransfers", "WarehouseSales"].agg('mean').plot(figsize = (10,5))

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data.groupby(["Year", "Month" ])["RetailSales", "RetailTransfers", "WarehouseSales"].agg('mean').plot.bar(figsize = (10,5))

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data.pivot_table(index=["Year", "Month"], columns = ["ItemType"], values = ["RetailSales"], aggfunc = sum).plot(figsize = (15,10))

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
data.pivot_table(index=["Year", "Month"], columns = ["ItemType"], values = ["RetailSales"], aggfunc = sum).plot.bar(figsize = (15,10))

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(x="RetailSales", y="RetailTransfers", color = 'r', data=data)

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(data, hue="ItemType", palette  ="husl")
